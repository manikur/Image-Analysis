# %% [markdown]
# <a href="https://colab.research.google.com/github/manikur/Image-Analysis/blob/main/ImageAnalysisNew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2

# %%
img=cv2.imread('/content/italy2018.jpg')

# %%
img[0]
# Out:
# array([[61, 68, 55],
#        [47, 54, 41],
#        [54, 61, 48],
#        ...,
#        [53, 59, 54],
#        [48, 54, 49],
#        [52, 58, 53]], dtype=uint8)

# %%
img1=cv2.imread('/content/footballSocu.png')

# %%
img1[0]
# Out:
# array([[248, 255, 244],
#        [247, 255, 243],
#        [248, 255, 244],
#        ...,
#        [250, 255, 243],
#        [ 28,  27,  23],
#        [255, 254, 255]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(img1)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
b,r,g=cv2.split(img)

# %%
b
# Out:
# array([[ 61,  47,  54, ...,  53,  48,  52],
#        [ 51,  37,  44, ...,  40,  35,  39],
#        [ 54,  40,  46, ...,  44,  40,  43],
#        ...,
#        [147, 131, 114, ..., 191, 150, 111],
#        [149, 130, 114, ..., 190, 150, 113],
#        [153, 125, 106, ..., 185, 150, 116]], dtype=uint8)

# %%
r
# Out:
# array([[ 68,  54,  61, ...,  59,  54,  58],
#        [ 58,  44,  51, ...,  46,  41,  45],
#        [ 61,  47,  53, ...,  51,  47,  50],
#        ...,
#        [193, 187, 185, ..., 195, 149, 108],
#        [193, 183, 185, ..., 194, 149, 110],
#        [194, 178, 177, ..., 190, 149, 113]], dtype=uint8)

# %%
g
# Out:
# array([[ 55,  41,  48, ...,  54,  49,  53],
#        [ 45,  31,  38, ...,  41,  36,  40],
#        [ 48,  34,  40, ...,  44,  40,  43],
#        ...,
#        [187, 176, 168, ..., 230, 217, 193],
#        [187, 174, 168, ..., 229, 217, 195],
#        [189, 169, 160, ..., 223, 217, 198]], dtype=uint8)

# %%
plt.hist(img.ravel(),256,[0,256])
plt.show()
# Out:
# <ipython-input-14-9703f453e98c>:1: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img.ravel(),256,[0,256])

# %%
plt.hist(img1.ravel(),256,[0,256])
plt.show()
# Out:
# <ipython-input-15-7ca721c3d116>:1: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img1.ravel(),256,[0,256])

# %%
cv2.imwrite('italy.jpg',img)
# Out:
# True

# %%
img.shape
# Out:
# (437, 678, 3)

# %%
img1.shape
# Out:
# (315, 482, 3)

# %%
img3,img4=cv2.resize(img,(200,200)),cv2.resize(img1,(200,200))

# %%
img3.shape
# Out:
# (200, 200, 3)

# %%
img4.shape
# Out:
# (200, 200, 3)

# %%
img5=cv2.add(img3,img4)

# %%
plt.imshow(img5)

# %%
plt.imshow(cv2.cvtColor(img5,cv2.COLOR_BGR2RGB))
plt.show()

# %%
img6=cv2.subtract(img3,img4)
plt.imshow(img6)

# %%
img7=cv2.subtract(img4,img3)
plt.imshow(img7)

# %%
imgN=img3*img4
plt.imshow(imgN)

# %%
img7=cv2.addWeighted(img3,0.5,img4,0.5,0)
plt.imshow(img7)
